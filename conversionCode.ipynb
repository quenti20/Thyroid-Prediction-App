# %%
import pandas as pd

# %%
# Define the data
data = [
    {
        "Age": 29,
        "Sex": "female",
        "Height": 165,
        "Weight": 56,
        "BMI": 20.57,
        "Body fat": 34,
        "Hand grip dominant hand": 23,
        "Hand grip non-dominant hand": 21,
        "Wrist circumference dominant": 13,
        "Wrist circumference non-dominant": 13,
        "Serum T3": 0.21,
        "Serum T4": 3.32,
        "TSH": 9.23,
        "Thyroid": "Hypothyroid"
    },
    {
        "Age": 28,
        "Sex": "male",
        "Height": 174,
        "Weight": 78.6,
        "BMI": 25.8,
        "Body fat": 23,
        "Hand grip dominant hand": 46,
        "Hand grip non-dominant hand": 39,
        "Wrist circumference dominant": 18,
        "Wrist circumference non-dominant": 17.6,
        "Serum T3": 0.98,
        "Serum T4": 8.32,
        "TSH": 4.34,
        "Thyroid": "Normal"
    },
    {
        "Age": 41,
        "Sex": "male",
        "Height": 169,
        "Weight": 68.5,
        "BMI": 23.98,
        "Body fat": 17.5,
        "Hand grip dominant hand": 32,
        "Hand grip non-dominant hand": 31.8,
        "Wrist circumference dominant": 16,
        "Wrist circumference non-dominant": 15.4,
        "Serum T3": 0.58,
        "Serum T4": 4.3,
        "TSH": 6.7,
        "Thyroid": "Hypothyroid"
    }
]

# Create a DataFrame
df = pd.DataFrame(data)

# Export DataFrame to CSV
df.to_csv("health_data.csv", index=False)

print("Data has been exported to 'health_data.csv'")
# Out:
# Data has been exported to 'health_data.csv'

# %%
# Out:
#    Age     Sex  Height  Weight    BMI  Body fat  Hand grip dominant hand  \
# 0   29  female     165    56.0  20.57      34.0                       23
# 1   28    male     174    78.6  25.80      23.0                       46
# 2   41    male     169    68.5  23.98      17.5                       32
#
#    Hand grip non-dominant hand  Wrist circumference dominant  \
# 0                         21.0                            13
# 1                         39.0                            18
# 2                         31.8                            16
#
#    Wrist circumference non-dominant  Serum T3  Serum T4   TSH      Thyroid
# 0                              13.0      0.21      3.32  9.23  Hypothyroid
# 1                              17.6      0.98      8.32  4.34       Normal
# 2                              15.4      0.58      4.30  6.70  Hypothyroid
